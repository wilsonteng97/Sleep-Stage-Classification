# %%
import matplotlib.pyplot as plt
 
name_list = ['Artificial Neural Network','Support Vector Machine','Random Forest','K Nearest Neighbours', 'Classification Tree', 'Naive Bayes', 'Logistic Regression']
num_list = [0.95,0.798,0.854,0.83,0.826,0.853,0.707]
plt.barh(range(len(num_list)), num_list,tick_label = name_list)
plt.title('Test accuracy of different models')
plt.show()

# %%
name_list = ['Num_hidden = [64, 32]','No dropout','batch=64', 'LR = 0.1', '256-64-32']
num_list = [0.885,0.933,0.903,0.922, 0.95]
plt.barh(range(len(num_list)), num_list,tick_label = name_list)
plt.title('Test accuracy of different ANN structures (first row has num_hidden=[256, 64, 32], drop=0.2, lr=0.003, batch=16), others are control groups')
plt.show()
